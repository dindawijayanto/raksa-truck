# %% [markdown]
# # Model A — Kekasaran Jalan Relatif untuk Semua Sesi
#
# Notebook ini adalah lapisan eksplorasi. Semua logika produksi berada di `src/aic/model_a.py`, sehingga dashboard dan CLI menjalankan pipeline yang sama. Skor 0–100 bersifat **relatif per sesi**; ia bukan IRI absolut dan tidak boleh diranking lintas perangkat/kendaraan.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if not (PROJECT_ROOT / 'src').exists():
    PROJECT_ROOT = next(parent for parent in PROJECT_ROOT.parents if (parent / 'src').exists())
sys.path.insert(0, str(PROJECT_ROOT / 'src'))

from aic import RoughnessConfig, process_all_archives, write_model_a_artifacts, write_model_a_outputs

config = RoughnessConfig()
report = process_all_archives(PROJECT_ROOT / 'data', config)
write_model_a_outputs(report, PROJECT_ROOT / 'reports' / 'model_a', config)
write_model_a_artifacts(report, PROJECT_ROOT / 'models' / 'model_a')
report.archive_audit

# %%
report.session_summary.sort_values('session_id')

# %%
report.segments.loc[:, ['session_id', 'segment_id', 'relative_roughness_score', 'roughness_class', 'hotspot_flag']].head()
